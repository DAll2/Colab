# %% [markdown]
# **Ejercicios**
# Python: Relaciones entre clases
# Desarrollar una relación de clases, teniendo en cuenta que en una tienda tiene las clases cliente, producto, venta y proveedor, agregue los atributos y métodos necesarios para completar el programa.
