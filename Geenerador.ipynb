# %%
def func(a):
    yield a
a=[1,2,3]
 
b=func(a)
next(b)
# Out:
# [1, 2, 3]

# %%
def func(a):
    return a
a=[1,2,3]
func(a)
# Out:
# [1, 2, 3]

# %%
def myfunc(a):
  while a>=3:
    yield a
    a=a+1
b =  myfunc(a)
print(b)
next(b)
# Out:
# <generator object myfunc at 0x7fbb329fdcd0>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-ef978937959e> in <module>()
#       5 b =  myfunc(a)
#       6 print(b)
# ----> 7 next(b)
#
# <ipython-input-20-ef978937959e> in myfunc(a)
#       1 def myfunc(a):
# ----> 2   while a>=3:
#       3     yield a
#       4     a=a+1
#       5 b =  myfunc(a)
#
# TypeError: '>=' not supported between instances of 'list' and 'int'
