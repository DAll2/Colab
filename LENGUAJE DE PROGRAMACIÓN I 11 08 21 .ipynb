# %% [markdown]
# Realizar un programa que utilice de una clase llamada Estudiante que tenga como atributos el nombre, apellidos y la calificación del Estudiante. Definir los métodos para inicializar sus atributos, imprimirlos y mostrar un mensaje con el resultado de la nota y si ha aprobado o no teniendo en cuenta que la nota aprobatoria
# es de 10.5

# %%
class Estudiante():
	# Atributos
	apellidos = ""
	nombre = ""
	edad = 0
	despierto = False

	# Funcionalidad
	def despertar(self):
		self.despierto = True
		print("¡Buen dia!")

	def dormir(self):
		self.despierto = False
		print("¡Buena noche!")

#Instanciar la clase persona
persona1 = Persona()

persona1.apellidos = "Begazo"
persona1.nombre = "Juan"
persona1.despertar()

print(persona1.apellidos)
print(persona1.nombre)
print(persona1.edad)

# %%
class Persona():
  	def Nombre(self):
		self.nombre = True
		print("¡Buen dia!")
  	def Apellido(self):
		self.apellido = True
		print("¡Buen dia!")
  	def Edad(self):
		self.edad = True
		print("¡Buen dia!")

# %% [markdown]
# Realizar un programa en el cual se declare dos valores enteros por teclado utilizando el método __init__.
# Calcular despúes la suma, resta, multiplicación y división. Utilizar el método para cada una e imprimir los resultados obtenidos. Llamar a la clase Calculadora.
