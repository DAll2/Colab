# %%
import numpy as np

# %% [markdown]
# 1.1. Calculos con una y varias variables

# %%
t=2;
x=2*t**3+5*t**2+5;
print(x)
# Out:
# 41

# %%
t=2
xo=5
vo=2.5
a=9.8
x=xo+vo*t+a*t**2/2
print(x)
# Out:
# 29.6

# %%
for t in range(1,9):
  x=2*t**3+5*t**2+5;
  print([t,x]);
# Out:
# [1, 12]
# [2, 41]
# [3, 104]
# [4, 213]
# [5, 380]
# [6, 617]
# [7, 936]
# [8, 1349]

# %%
t=0;
while t<8:
  t=t+1;
  x=2*t**3+5*t**2+5;
  print([t,x]);
# Out:
# [1, 12]
# [2, 41]
# [3, 104]
# [4, 213]
# [5, 380]
# [6, 617]
# [7, 936]
# [8, 1349]

# %% [markdown]
# Ejercicios
# 1. Ejecute las siguientes instrucciones
#
# a = [4 1 3; 2 6 5; 9 7 8]’
#
# b = [9; 6; 8; 5; 2]
#
# c = b(2:5)
#
# d = b(4:-1:1)
#
# e = sort(b)
#
# f = sum(b)
#
# g = max(b)
#
# h = sort(a)
#
# m = sum(a)
#
# n = min(a)

# %%
a=np.array([[4,1,3],[2,6,5],[9,7,8]]).T   ## transpuesta
print(a)
print(a.shape)  ## Filas y columnas de la matriz a
# Out:
# [[4 2 9]
#  [1 6 7]
#  [3 5 8]]
# (3, 3)

# %%
b=np.array([[9],[6],[8],[5],[2]])
print(b)
# Out:
# [[9]
#  [6]
#  [8]
#  [5]
#  [2]]

# %%
c=b[1:5]
print(c)
# Out:
# [[6]
#  [8]
#  [5]
#  [2]]

# %%
d = b[np.array([3,2,1,0])]
print(d)
# Out:
# [[5]
#  [8]
#  [6]
#  [9]]

# %%
e=np.sort(b)[::-1]
print(e)
# Out:
# [[2]
#  [5]
#  [8]
#  [6]
#  [9]]

# %%
f=np.sum(b)
print(f)
# Out:
# 30

# %%
g=np.max(b)
print(g)
# Out:
# 9

# %%
h=np.sort(a)
print(h)
# Out:
# [[2 4 9]
#  [1 6 7]
#  [3 5 8]]

# %%
m=np.sum(A)
print(m)
# Out:
# 45

# %%
n=np.min(a)
print(n)
# Out:
# 1
