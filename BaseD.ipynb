# %% [markdown]
# **Regresión**

# %% [markdown]
# Generar una base de datos para un problema de regresión de acuerdo con el siguientes código. Debe reemplazar la variable code con los últimos 5 dígitos de su código de estudiante. Es decir, la variable code es igual a la suma de los últimos cinco dígitos de su código de estudiante.

# %%
import numpy as np
import matplotlib.pyplot as plt
code = 32923
np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 2000)
y = x - 2 * (x * 2) + 0.5 * (x * 3) + code*np.random.normal(-3, 3, 2000)
plt.scatter(x,y, s=10)
plt.show()

# %% [markdown]
# **1.- Visualizar los datos y comentar su primera impresión sobre el problema.**

# %% [markdown]
# **2.- Entrenar un modelo que sub ajuste el problema.**

# %% [markdown]
# **3.- Entrenar un modelo que sobre ajuste el problema. **

# %% [markdown]
# **4.- Entrenar un modelo que generalice el problema.**

# %% [markdown]
# **5.- Elabore una tabla donde se pueda visualizar las prestaciones en entrenamiento y test de los tres modelos entrenamos. Puede elegir cualquier métrica que considere adecuado para el problema.**

# %% [markdown]
# **6.- Realice una discusión de sus resultados y  escriba sus conclusiones.**
