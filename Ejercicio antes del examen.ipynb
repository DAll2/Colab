# %%
nombrec=input("Escriba el nombre completo de una persona")
nombre=nombrec.title()
for i in range(len(nombre)+1):
  if i==len(nombre) and ' '==nombre:
    abre==nombre[-1]
    print(abre)
print(nombre)
# Out:
# Escriba el nombre completo de una personaaldo quispe avendaño
# Aldo Quispe Avendaño
